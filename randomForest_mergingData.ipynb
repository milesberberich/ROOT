# %% [markdown]
# ## 0. Purpose
# To train a large Random Forest model on the basis of all the data (n22, s20, s22, n23), all the data gets merged into one dataset. Each datapoint gets a timestemp label. The data is saved so it can easily be loaded into the random forest script.

# %% [markdown]
# # 1. Importing libraries

# %%
#%pip install xarray rioxarray pandas matplotlib rasterio
import geopandas as gpd
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import rioxarray
from rasterio import rio
from rasterio import features
from rasterio.enums import Resampling
import numpy as np
from rasterio.transform import Affine
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Importing data

# %%
n22 = rioxarray.open_rasterio(r"C:\Users\miles\OneDrive\Dokumente\ROOT\trainingdata_collection\trainingdata_withindices\n22.tif")
n23 = rioxarray.open_rasterio(r"C:\Users\miles\OneDrive\Dokumente\ROOT\trainingdata_collection\trainingdata_withindices\n23.tif")
s20 = rioxarray.open_rasterio(r"C:\Users\miles\OneDrive\Dokumente\ROOT\trainingdata_collection\trainingdata_withindices\s20.tif")
#s22 = rioxarray.open_rasterio(r"C:\Users\miles\OneDrive\Dokumente\ROOT\trainingdata_collection\trainingdata_withindices\s22.tif")

# %% [markdown]
# ## 3. Adding timestemps

# %%
new_slice = xr.full_like(n22.isel(band=0).expand_dims(band=['timestemp']), "Value", dtype=object)
n22 = xr.concat([n22, new_slice], dim='band')

new_slice = xr.full_like(n23.isel(band=0).expand_dims(band=['timestemp']), "Value", dtype=object)
n23 = xr.concat([n23, new_slice], dim='band')

new_slice = xr.full_like(s20.isel(band=0).expand_dims(band=['timestemp']), "Value", dtype=object)
s20 = xr.concat([s20, new_slice], dim='band')

# new_slice = xr.full_like(s22.isel(band=0).expand_dims(band=['timestemp']), "Value", dtype=object)
# s22 = xr.concat([s22, new_slice], dim='band')
